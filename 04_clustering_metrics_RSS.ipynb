# %% [markdown]
# # Gauge the quality of the clusters produced - RSS corpus

# %%
import lib.reporter as reporter

# %%
lda_stats, lda_coherences, lda_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_lda.csv")

for key, value in lda_stats.items():
    if "examples" not in key:
        print (key, value)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# c_v 0.4601
# c_npmi 0.0042
# macro_time_coherence 129229.64446352441
# micro_time_coherence 105555.9573011889
# Average document word count 39.30280635810531
# Number of documents 31393
# Latest record Fri, 01 May 2020 00:18:25 GMT
# Earliest record Wed, 9 Oct 2019 21:52:38 +0000
# Number of clusters 35
# Median cluster size 667.0
# Percent clustered docs 100.0

# %%
for key, value in lda_stats.items():
    if "examples" in key:
        print (key, value)
# Out:
# examples_best_performant [{'examples': [(0.002325600419957105, 'Kylie Rae Harris dead at 0 – US country singer killed along with girl, 16, in horror crash. COUNTRY singer Kylie Rae Harris has been killed in a horror car crash in America hours after posting a heartbreaking video to her fans. The 0-year-old star died along with a 16-year-old girl in the three-car crash in New Mexico on Wednesday. Police confirmed two drivers 8211; 0-year-old woman and a 16-year-old girl 8211; were [820;]'), (0.002179913717696829, 'Kylie Rae Harris crash – US country singer killed caused three-car smash that killed her and an innocent schoolgirl, Texas cops say. COUNTRY singer Kylie Rae Harris was caused the three-car crash that took her life and killed a teenage girl, cops have claimed. The 0-year-old star was allegedly speeding before she clipped a car in front and ploughed into oncoming traffic in New Mexico on Wednesday. Police confirmed two drivers 8211; Kylie and 16-year-old Maria Cruz [820;]'), (0.001991838679382087, 'Girl, 5, raped in grounds of heavily guarded US Embassy in Delhi ‘by 25-year-old driver’. A MAN has been arrested after allegedly raping a five-year-old girl on the heavily guarded premises of the US embassy in the Indian capital, Delhi. The 25-year-old was arrested on Sunday after the childs parents registered a police complaint, cops said. Doctors confirmed the girl was raped on Saturday and have said she is is [820;]'), (0.001981625878616416, "Girl, 12, becomes 'youngest to die in Europe' after catching coronavirus. The 12-year-old girl died while being treated for coronavirus at a hospital in Belgium and her death follows those of a 12-year-old boy in Portugal and a 16-year-old girl in France"), (0.001925277359598574, 'Three family members found dead in backyard pool after possible electrical error. Police say an eight-year-old girl, her 2-year-old mother, and her 62-year-old grandfather all drowned')], 'entities': [('820', 318), ('TWO', 119), ('MEXICO', 118), ('US', 85), ('THREE', 58), ('1', 48), ('ONE', 46), ('FOUR', 37), ('BRITISH', 31), ('AUSTRALIA', 31)], 'nouns': [('MEXICO', 157), ('US', 88), ('CORONAVIRUS', 71), ('GIRL', 55), ('NEW', 45), ('MADELEINE', 39), ('WEDNESDAY', 34), ('AUSTRALIA', 34), ('MCCANN', 34), ('MARIA', 31)]}, {'examples': [(0.0010618485436156722, 'Trump news: President claims he fired John Bolton, as former security adviser texts Fox News hosts live to say this isnt true. Donald Trump claimed he fired John Bolton in a tweet on Tuesday as polls showed his approval rating falling 8 per cent, down six points on his July career-best according to a new ABC News/Washington Post, as concerns over the fate of the American economy linger.'), (0.0010618283049505961, 'Democrat congresswoman says notorious LA gangs have more integrity than Donald Trump. Maxine Waters compares president to the Crips and Bloods'), (0.0010129698814149253, 'Who is Tiffany Trump? Daughter of Donald Trump and Marla Maples and star on Instagram. EVEN if you hadnt heard of her before, youre sure to be familiar with Tiffany Trump by now. Shes the 25-year-old daughter of President of the US Donald Trump, and she was there to support her dad every step of the way in his race to the White House. Who is Tiffany Trump? Tiffany is the [820;]'), (0.0010104321205181243, "Trump claims Biden too scared to debate him – hours after former vice president challenges him to one. Presumptive Democratic nominee says he'd challenge the incumbent president to a debate 'anytime, anywhere'"), (0.0009906908289268514, 'Donald Trump must be impeached says Joe Biden as he blasts ‘blatant abuse of power’ over Ukraine scandal… but defiant president won’t back down. JOE Biden has said he believes Donald Trump committed an impeachable offence by pressuring the Ukrainian president to dig dirt on him and his son. It was the furthest he has gone on the subject of Trumps impeachment 8211; which most of the other leading Democratic presidential contenders have already ...
# examples_worst_performant [{'examples': [(0.0029640274150600273, 'Taliban warns it will ‘fight for a hundred years’ and kill more Americans after Trump scraps secret peace talks. MANIAC Taliban leaders have vowed to fight on for a hundred years after Donald Trump scrapped peace talks with the sick militant group. The US President said he called off Sundays planned meeting at his Camp David retreat after a car bomb attack in Afghanistan claimed the lives of 12 people including an American soldier. [820;]'), (0.0024237141124223587, 'Afghan conflict: Trump hails deal with Taliban to end 18-year war. The US president says 5,000 troops will leave Afghanistan by May and he will meet Taliban leaders.'), (0.0024235965765786577, 'How is Trump influenced by religion?. The president has surrounded himself with evangelical leaders, is he learning from them?'), (0.0023525033123842553, "Trump delays 'outdated' G7 leaders' summit. The US president says he is postponing this year's meeting and wants to invite other leaders as well."), (0.002345240938888303, 'Trump says Jerusalem will be Israels undivided capital under Middle East peace plan. Palestinians leaders have called for a boycott of the plan')], 'entities': [('US', 238), ('TRUMP', 180), ('TALIBAN', 114), ('AFGHANISTAN', 110), ('820', 91), ('FIRST', 36), ('RUSSIA', 35), ('SYRIA', 34), ('IRAN', 30), ('TWO', 29)], 'nouns': [('US', 240), ('TRUMP', 197), ('CORONAVIRUS', 150), ('TALIBAN', 131), ('PRESIDENT', 119), ('AFGHANISTAN', 110), ('DAVID', 54), ('SYRIA', 36), ('HOUSE', 36), ('RUSSIA', 35)]}, {'examples': [(0.0048958269837403225, 'Hunt for cruel woman who stubbed cigarette out in a puppy’s eye and filmed it ‘for animal torture fetish site’. ANIMAL rights groups were today hunting a cruel woman who was filmed stubbing out a cigarette on a puppys eye. The Society for the Prevention of Cruelty to Animals in Singapore has launched an investigation after being alerted to the sadistic video showing the dog in utter agony. Footage shows how the woman holds a [820;]'), (0.003452308372403195, 'Woman pokes cigarette in puppy’s eye for ‘animal torture fetish site’. WARNING: GRAPHIC CONTENT Society for the Prevention of Cruelty to Animals in Singapore has started the hunt for a woman who burnt a small puppy with a cigarette'), (0.0029157581572269594, "Studio Ghibli: Netflix buys rights to iconic animated films. From February, 21 of the studio's iconic films will be available on Netflix."), (0.0028328812075735627, "Coronavirus: Woman screams as she's barricaded in home to 'stop bug spreading'. Distressing footage shows a group of men fitting thick metal bars over the main door while the woman screams in terror. Because of censorship laws in China, it is not clear where the video was filmed"), (0.0027990552073367553, '‘Wonderful’ Brit woman, 61, ‘eaten alive by pack of feral dogs she cared for at Egyptian animal shelter’. A Brit woman who worked at an Egyptian animal shelter was 8216;eaten by a pack of dogs she helped care for, police claim. Anne Johnson, 61, who is thought to have grown up in Macclesfield, was found dead at the shelter in the Red Sea city of Dahab on Friday afternoon. Officers called to the [820;]')], 'entities': [('820', 146), ('US', 40), ('ONE', 36), ('TWO', 31), ('CHINESE', 22), ('CHINA', 21), ('THREE', 20), ('AUSTRALIA', 20), ('WUHAN', 20), ('CORONAVIRUS', 18)], 'nouns': [('CORONAVIRUS', 112), ('US', 42), ('CHINA', 23), ('WUHAN', 23), ('COVID-1', 22), ('AUSTRALIA', 21), ('CONTENT', 18), ('TRUMP', 17), ('NEW', 17), ('THAILAND', 17)]}, {'examples': [(0.006307465927122429, 'Inside Michael Jackson’s creepy jungle gym where paedo pop star held parties for terminally ill kids at his Neverland Ranch. MICHAEL Jackson’s creepy jungle gym where he invited terminally ill kids to play is up for sale for £1.4million. The alleged paedophile had the hollowed-out tree installed at his Neverland Ranch in California from 14 to 2005. It is surrounded by a collection of bronze animal sculptures wh ...
# examples_populous [{'examples': [(0.0004255129288650798, 'Coronavirus LIVE: More cases ‘highly likely’ in UK as 45 million deaths are forecast by experts. THE deadly Coronavirus has hit London with the capitals first patient being taken into St Thomas Hospital for treatment. Experts are now warning that more cases in the UK are highly likely with world health bosses fearing that Covid-1 virus could kill as many as 45 million globally. Read our Coronavirus live blog for the [820;]'), (0.0004199552785734857, 'Coronavirus news LIVE: Pandemic declared as EIGHTH person dies in the UK from COVID-1. WORLD Health Organisation officials are warning national governments its time for aggressive action as the outbreak was declared a pandemic. There are now more than 118,000 cases in 114 countries and 4,21 deaths, but this could just be the beginning of a devastating crisis. It comes as UK coronavirus cases rise to 460 and the [820;]'), (0.00041291659482309783, "There were no red flags: New Orleans mayor says Trump made her think it was safe to go ahead with Mardi Gras which likely infected hundreds with coronavirus. As another pandemic hotspot appears in New Orleans, the city's Mayor says president Trump did not warn her about the risks of holding Mardi Gras amid coronavirus"), (0.0004127764555611228, 'Kim Jong-un was just hiding away from coronavirus and wasn’t remotely unwell, South Korean spy agency says. KIM Jong-un was just hiding from the coronavirus and did not have heart surgery, South Korea has claimed. North Koreas secretive leader reappeared for the first time in 20 days last week amid swirling rumours about his health. ⚠️ Read our coronavirus live blog for the latest news 8; updates Even as Kim appeared well [820;]'), (0.00040819740860985153, 'Hazmat cops drag screaming ‘coronavirus’ patients from homes as UK scientist warns its TEN TIMES worse than feared. HARROWING footage has emerged showing three people, allegedly infected with the deadly coronavirus being dragged from their home by hazmat-clad officials as they scream and yell. The death toll has now climbed past 700 as a UK-based scientist warns the virus is TEN TIMES worse than feared. Read our coronavirus live blog for all the latest [820;]')], 'entities': [('820', 1134), ('US', 762), ('UK', 697), ('CHINA', 471), ('CORONAVIRUS', 424), ('TRUMP', 387), ('KIM JONG-UN', 323), ('NORTH KOREA', 311), ('FIRST', 282), ('JAPAN', 248)], 'nouns': [('CORONAVIRUS', 2416), ('US', 782), ('UK', 752), ('KOREA', 548), ('KIM', 547), ('CHINA', 488), ('UN', 478), ('JONG', 471), ('NORTH', 463), ('TRUMP', 451)]}, {'examples': [(0.0008329480379979055, 'Italy coronavirus deaths hit 11,51 as top scientist says UK style lockdown isn’t working and families should separate. CORONAVIRUS deaths in Italy rose to 11,51 today as experts fear lockdown measures used in European countries — including the UK — are not working. Now a prominent Italian scientist is calling on his government to change its strategy by separating people with suspected Covid-1 symptoms from their families. ⚠️ Read our coronavirus live blog [820;]'), (0.0008244735227387717, 'Coronavirus – Italy overtakes China with ,405 Covid-1 deaths… but study reveals % of victims had existing illnesses. ITALY has overtaken China for the number of coronavirus deaths after 427 more died from the disease. The country has now seen ,405 people die from the coronavirus, which began in the Chinese city of Wuhan, and per cent of them had pre-existing medical conditions. ⚠️ Read our coronavirus live blog for the latest [820;]'), (0.0008032499830491329, 'Coronavirus kills 7 people in a single DAY in Italy as convoys of army trucks ferry bodies to cemeteries. TROOPS are working round-the-clock to move coffins in Italy after the coronavirus pandemic claimed the lives of 7 people in a single day. The total number of dead in the hardest-hit country in the world soared to 4,825 today 8211; the worst day for fatalities since the crisis began. ⚠️ Read our coron ...

# %%
w2v_stats, w2v_coherences, w2v_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_w2v_pca.csv")

for key, value in w2v_stats.items():
    if "examples" not in key:
        print (key, value)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# c_v 0.5195
# c_npmi 0.0446
# macro_time_coherence 1918335.919028377
# micro_time_coherence 184087.54283666002
# Average document word count 39.30280635810531
# Number of documents 31393
# Latest record Fri, 01 May 2020 00:18:25 GMT
# Earliest record Wed, 9 Oct 2019 21:52:38 +0000
# Number of clusters 257
# Median cluster size 13.0
# Percent clustered docs 33.9

# %%
# Formatted best examples
example_df = reporter.format_examples(w2v_stats['examples_best_performant'][1])
example_df.to_csv("outputs/RSS_w2v_pca_best.csv", index=False)
example_df
# Out:
#    TextRank Score                                               Text  \
# 0        0.136516  New Zealand volcano victims could be entombed ...
# 1        0.126793  New Zealand PM says country will not open bord...
# 2        0.125963  New Zealand volcano: Two Britons among those i...
# 3        0.125915  New Zealand volcano: Boy, 7, and newlyweds amo...
#
#           Entities  Entities Count
# 0      NEW ZEALAND               8
# 1             FIVE               3
# 2  GRACE MILLANE'S               2
# 3         AUCKLAND               2

# %%
example_df = reporter.format_examples(w2v_stats['examples_populous'][2])
example_df.to_csv("outputs/RSS_w2v_pca_pop.csv", index=False)
example_df
# Out:
#    TextRank Score                                               Text  \
# 0        0.003552  Coronavirus: Trumps immigration policies may h...
# 1        0.003497  Coronavirus dreams: Why are people having lock...
# 2        0.003169  Computer games: More than a lockdown distracti...
# 3        0.003161  Why are so many coronavirus victims around the...
#
#       Entities  Entities Count
# 0           US             135
# 1  CORONAVIRUS              93
# 2        TRUMP              17
# 3      CHINESE              16

# %%
for key, value in w2v_stats.items():
    if "examples" in key:
        print (key, value)
# Out:
# examples_best_performant [{'examples': [(0.14479604722423678, 'Kim Jong-un dead rumours resurface as Japan reveals it has ‘some suspicions’ about state of North Korean tyrant’s health. JAPAN has revealed it has “some suspicions” about the health of the periodically missing North Korean dictator Kim Jong-un.160;160; The country’s defence minister made the bombshell comment at a press briefing and added he thought recent movements in the secretive state were “all very strange”. Following his first disappearing act, reports emerged claiming the enigmatic [820;]'), (0.14479604722423678, 'Kim Jong-un dead rumours resurface as Japan reveals it has ‘some suspicions’ about state of North Korean tyrant’s health. JAPAN has revealed it has “some suspicions” about the health of the periodically missing North Korean dictator Kim Jong-un. The country’s defence minister made the bombshell comment at a press briefing and added he thought recent movements in the secretive state were “all very strange”. Following his first disappearing act, reports emerged claiming the enigmatic [820;]'), (0.14210681185897206, 'Kim Jong-un: North Korean leader rides horse up sacred mountain. Images of Kim Jong-un astride a white steed on Mount Paektu fuels speculation of a major announcement.'), (0.14210681185897206, 'Kim Jong-un: North Korean leader rides horse up sacred mountain. Images of Kim Jong-un astride a white steed on Mount Paektu fuel speculation of a major announcement.'), (0.11303404701424537, "Kim Jong-un 'went into hiding because bodyguard had suspected coronavirus'. North Korea's state media has so far made no mention of dictator Kim Jong-un being absent or about his health amid unverified claims that he is dead, in a coma or alive and recovering in Wonsan after heart surgery")], 'entities': [('KIM JONG-UN', 9), ('NORTH KOREAN', 6), ('JAPAN', 4), ('NORTH KOREA', 3), ('US', 3), ("NORTH KOREA'S", 3), ('MOUNT PAEKTU', 2), ('TWO', 2), ('FIRST', 2), ('820', 2)], 'nouns': [('KIM', 13), ('JONG', 12), ('UN', 11), ('KOREA', 7), ('NORTH', 6), ('JAPAN', 4), ('US', 3), ('MOUNT', 2), ('PAEKTU', 2), ('THANKSGIVING', 1)]}, {'examples': [(0.13651602317554468, 'New Zealand volcano victims could be entombed like Pompeii if rain falls as troops in ‘Chernobyl’ suits scour for bodies. VICTIMS of the deadly volcano eruption in New Zealand could be entombed like Pompeii if rainfall hits the area as troops wearing Chernobyl-style suits scour for bodies. The volcano, a popular tourist destination for day-trippers, erupted on Monday 8211; spewing ash and steam with 47 people on the island. Incredible photos taken from above White [820;]'), (0.1267927598538374, 'New Zealand PM says country will not open borders for a ‘long time’ despite ‘eliminating’ coronavirus. THE Prime Minister of New Zealand has said the countrys borders will remain closed for a long time. The country has recorded a death rate of just one per cent 8211; but PM Jacinda Arden announced plans to keep borders closed for the foreseeable future. Speaking following discussion with Australian Ministers on the issue of [820;]'), (0.12596267752052087, 'New Zealand volcano: Two Britons among those injured after deadly eruption. Five with a UK birthplace still marked missing on Red Cross list updated by public'), (0.12591532196583574, 'New Zealand volcano: Boy, 7, and newlyweds among more than 8 tourists missing. Recently married James and Madeleine Whitehouse are yet to be found with five Brits unaccounted for nearly 24 hours on from the White Island eruption which has so far claimed five lives'), (0.12534191004584883, 'Ive been an idiot: New Zealands health minister breaks lockdown to go for trip to the beach. Prime minister Jacinda Ardern says she would have sacked him under normal circumstances')], 'entities': [('NEW ZEALAND', 8), ('FIVE', 3), ("GRACE MILLANE'S", 2), ('AUCKLAND', 2), ('JUST MONTHS', 2), ('CHERNOBYL', 2), ('820', 2), ('NEW ZEALAND DAD RYAN MEAD', 1), ('12 YEARS OLD', 1), ('25 YEARS', 1)], 'no ...
# examples_worst_performant [{'examples': [(0.08483837618410305, 'Passenger spits at air stewardess and slaps her face before being tackled in row ‘over elbow room’. A TOTALLY out of control passenger slapped an attendant to the floor after she slapped him for screaming and spitting at her during an altercation. The man allegedly became irate after Brussels Airline attendants refused to help his mother in law who was being elbowed by two men on either side of her on Friday [820;]'), (0.08411344980943239, 'Passenger spits at air stewardess and slaps her face before being tackled in row ‘over elbow room’. A TOTALLY out of control passenger slapped a stewardess to the floor after she slapped him for screaming and spitting at her during an altercation. The man allegedly became irate after Brussels Airline attendants refused to help his mother in law who was being elbowed by two men on either side of her on Friday [820;]'), (0.07252402677487012, 'Three men with ties to right-wing extremism arrested for planning violence at Las Vegas protest, prosecutors say. An informant helped law enforcement track men as they assembled Molotov cocktails to bring to Black Lives Matter demonstration'), (0.07251406355081651, 'LGBT rights: The film about gay love shaking up Georgia. Protests from priests and the far-right greet a new film amid a Church scandal over homosexuality.'), (0.07211033602225694, 'Amber alert for missing girl, 5, snatched from swings in New Jersey park and bundled into van. COPS believe a five-year-old girl has been abducted after she vanished from a park on Monday afternoon. Dulce Maria Alavez disappeared while she playing on some swings in Bridgeton, New Jersey, with her three-year-old brother at around 4.20pm. Police issued an amber alert on Tuesday night and said she had been abducted by a light-skinned, [820;]')], 'entities': [('820', 5), ('NEW JERSEY', 3), ('TWO', 3), ('5', 2), ('GERMAN', 2), ('0 MINUTES', 2), ('US', 2), ('BRUSSELS AIRLINE', 2), ('FRIDAY', 2), ('BLETCHLEY PARK', 2)], 'nouns': [('NEW', 3), ('JERSEY', 3), ('GAY', 2), ('TWITCH', 2), ('US', 2), ('BLACK', 2), ('ELBOW', 2), ('TOTALLY', 2), ('BRUSSELS', 2), ('AIRLINE', 2)]}, {'examples': [(0.059639437628049026, 'New Zealand volcano: Death toll rises to 16 after victim dies of severe burns in hospital. Divers are searching for two bodies still in waters off island'), (0.05952389224161521, 'New Zealand volcano: Police name missing two victims as death toll rises to 18. Harsh conditions preventing bodies from being located and returned'), (0.05809338706217633, 'New Zealand volcano eruption: Death toll rises to 1 after victim dies in hospital. Investigations into the disaster are underway'), (0.05694539005219522, "New Zealand volcano: Divers search for two bodies off coast after eruption. Police say conditions are 'challenging'"), (0.05586759932411423, "New Zealand to retrieve remaining bodies despite risk of eruptions as death toll rises. 'The chances of success will be determined by things beyond our control,' say police")], 'entities': [('NEW ZEALAND', 25), ('TWO', 6), ('EUROPEAN', 1), ('NEARLY EIGHT WEEKS', 1), ('TWO MONTHS', 1), ('ZERO', 1), ('EVERY YEAR', 1), ('8', 1), ('THE COMING DAYS', 1), ('SIX', 1)], 'nouns': [('NEW', 26), ('ZEALAND', 26), ('DECEMBER', 1)]}, {'examples': [(0.041598474243783844, 'Sicko raped girl, 11, three times after snatching her as she walked to school. A TWISTED dad has admitted to raping an 11-year-old girl three times after snatching her as she walked to school. Brett David Hill, 4, of New South Wales, Australia, forced the child into his car after he threatened her with a pair of scissors. She was abducted on June 12 last year, at around .15am [820;]'), (0.0409113190531251, 'Boy, 12, ‘rapes and strangles to death autistic girl, , in woods after luring her away from under mum’s nose. A NINE-year-old girl was led away by a 12-year-old boy who then raped and strangled her to death, according to police. Raíssa Caparelli went missing on ...
# examples_populous [{'examples': [(0.000517471675783415, 'Mum faces life in jail after being found guilty of shooting dead boy, 18, ‘who raped six-year-old daughter’. A MUM is facing life in jail after being found guilty of murdering a teenager accused of raping her six-year-old daughter. Connie Serbu, 4, has been convicted of second-degree murder following the death of Xavier Sierra, 18, who was shot dead in 2016 after being lured into an isolated area. During the week-long trial in [820;]'), (0.0005095687858322213, 'World’s oldest woman Jeanne Calment, 122, may have been a HOAX and could really have been her -year-old daughter. A WOMAN long believed to be the oldest ever may really have been her -year-old daughter out to fool the world. Frenchwoman Jeanne Calment made global headlines when she apparently died in 17 aged an incredible 122 years and 164 days. However one Russian academic says the woman who was buried was actually her daughter [820;]'), (0.0004943961193489637, 'Eurydice Dixon: Man who raped and murdered 22-year-old comedian walking home from gig jailed for life. Jaymes Todd sentenced to minimum of 5 years following brutal killing in Melbourne'), (0.0004918403638229753, 'Mum whose daughter was killed in tragic crash says baby has given her strength. Mum-of-five Amanda Furner, from Melbourne in Australia, was heavily pregnant when her car rolled over and tragically killed three-year-old Charlotte in October last year'), (0.0004861167421303488, 'Grieving family of black woman shot and killed in her own home by ‘confused’ white cop brands her death ‘murder’. THE family of a black woman shot and killed in her own home by a white police officer has branded her death a murder. Atatiana Jefferson, 28, died at her Texas home at around 2.0am on Saturday after the officer fired a single bullet through her bedroom window. Police were called to the house by [820;]')], 'entities': [('820', 1132), ('TWO', 272), ('US', 263), ('ONE', 175), ('THREE', 152), ('FIRST', 151), ('8211', 126), ('FOUR', 111), ('RUSSIAN', 106), ('2', 99)], 'nouns': [('US', 285), ('CORONAVIRUS', 134), ('INDIA', 95), ('AUSTRALIA', 89), ('BRAZIL', 72), ('MUM', 69), ('WORLD', 61), ('PAKISTAN', 53), ('TRUMP', 53), ('DE', 47)]}, {'examples': [(0.0012704676706086545, "Three-year-old girl dies after being thrown from 7th floor window. Detectives investigating why man committed 'such a horrific act', police spokesperson says"), (0.0012456643510816053, "7-year-old woman accused of killing 82-year-old neighbour with brick. Victim found dead in back garden after being hit 'multiple times with brick,' police say"), (0.0012169180259154126, 'Man takes dead body to police station and says he killed three more people. Shankar is now facing four murder charges'), (0.0011764048494697975, 'The /11 disease that’s given men breast cancer and already killed 2,000 heroes – and the death toll is set to overtake those that died on the day. WHILE thousands were running away from the deadly smoke, terror and carnage that was /11 8211; they were rushing in. Some 75,000 firefighters, police officers, paramedics and rescuers risked their own lives to save others after the terror attack 18 years ago. In the following days, people from every state 8211; and almost every single [820;]'), (0.001157666266221794, 'Man found dead in freezer left note saying wife did not kill him. Woman hid body for 10 years while still collecting government payments, detectives suspect')], 'entities': [('US', 216), ('820', 81), ('TWO', 74), ('ONE', 63), ('FOUR', 47), ('THREE', 45), ('INDIAN', 39), ('FIRST', 37), ('RUSSIAN', 37), ('TRUMP', 36)], 'nouns': [('US', 216), ('UN', 13), ('M', 6), ('£', 6), ('CO2', 5), ('F-16', 4), ('AFRICA', 4), ('VINT', 4), ('CERF', 4), ('INDIA', 4)]}, {'examples': [(0.0035517525455847185, 'Coronavirus: Trumps immigration policies may help spread deadly virus, healthcare experts warn. New rules may scare people away from hospitals or off their health insurance, encouraging the sprea ...

# %% [raw]
# w2v_stats, w2v_coherences, w2v_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_w2v_direct.csv")
#
# for key, value in w2v_stats.items():
#     if "examples" not in key:
#         print (key, value)

# %% [raw]
# kmd_stats, kmd_coherences, kmd_topics_results = reporter.report_corpus_model_coherence("working/RSS_kmeans_w2v_direct.csv")
#
# for key, value in kmd_stats.items():
#     if "examples" not in key:
#         print (key, value)

# %%
kmp_stats, kmp_coherences, kmp_topics_results = reporter.report_corpus_model_coherence("working/RSS_kmeans_w2v_pca.csv")

for key, value in kmp_stats.items():
    if "examples" not in key:
        print (key, value)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# c_v 0.5372
# c_npmi 0.0477
# macro_time_coherence 980373.499914767
# micro_time_coherence 253897.00589250113
# Average document word count 39.30280635810531
# Number of documents 31393
# Latest record Fri, 01 May 2020 00:18:25 GMT
# Earliest record Wed, 9 Oct 2019 21:52:38 +0000
# Number of clusters 197
# Median cluster size 56.5
# Percent clustered docs 100.0

# %%
# Formatted best examples
example_df = reporter.format_examples(kmp_stats['examples_best_performant'][0])
example_df.to_csv("outputs/RSS_kmp_pca_best.csv", index=False)
example_df
# Out:
#    TextRank Score                                               Text  \
# 0        0.081321  Prince Andrew Had Intimate Picnics with Jeffre...
# 1        0.079447  Jeffrey Epstein victim says he raped her bragg...
# 2        0.074382  Prince Andrew ‘utterly bewildered’ by ‘Mexican...
# 3        0.071251  Prince Andrew’s pal Peter Nygard ‘may have hun...
#
#           Entities  Entities Count
# 0              820              14
# 1    PRINCE ANDREW              14
# 2  JEFFREY EPSTEIN              13
# 3              FBI               6

# %%
# Formatted populous examples
example_df = reporter.format_examples(w2v_stats['examples_populous'][1])
example_df.to_csv("outputs/RSS_kmp_pca_pop.csv", index=False)
example_df
# Out:
#    TextRank Score                                               Text Entities  \
# 0        0.001270  Three-year-old girl dies after being thrown fr...       US
# 1        0.001246  7-year-old woman accused of killing 82-year-ol...      820
# 2        0.001217  Man takes dead body to police station and says...      TWO
# 3        0.001176  The /11 disease that’s given men breast cancer...      ONE
#
#    Entities Count
# 0             216
# 1              81
# 2              74
# 3              63

# %%
for key, value in kmp_stats.items():
    if "examples" in key:
        print (key, value)
# Out:
# examples_best_performant [{'examples': [(0.08132088004368178, 'Prince Andrew Had Intimate Picnics with Jeffrey Epstein’s ex-Beau Maxwell at Palace – Report. Earlier this month New York Post’s Page Six reported that the Duke of York allegedly begged Ghislaine to clear his name over the Epstein sex scandal and allegations that the royal slept with an underage girl. Ghislaine, who is accused of recruiting girls for Epstein, reportedly refused Andrew’s plea.'), (0.07944728670351607, 'Jeffrey Epstein victim says he raped her bragged about Prince Andrew as first pics of his ‘Paedophile Island’ emerge. A VICTIM of sex beast Jeffrey Epstein has told how he raped her on his private island — then bragged about his friendship with Prince Andrew. Chauntae Davies revealed the billionaire paedophile boasted about his links to Andrew and ex-wife Sarah Ferguson, and adorned his mansions with their pictures. His ex-masseuse also provided The Sun [820;]'), (0.07438226463126738, 'Prince Andrew ‘utterly bewildered’ by ‘Mexican stand-off’ over claims he refused to cooperate with FBI’s Epstein probe. PRINCE Andrew is said to be utterly bewildered by claims he has refused to co-operate with investigators probing the Jeffrey Epstein scandal. The under-fire royal is now locked in a Mexican standoff with prosecutors in the US, his friends have revealed. Prosecutor Geoffrey Berman has claimed Andrew has repeatedly declined a request to be interviewed. [820;]'), (0.07125074679102933, 'Prince Andrew’s pal Peter Nygard ‘may have hundreds of sex trafficking victims’, as he agrees to cooperate with FBI. PRINCE Andrew’s playboy pal Peter Nygard may have HUNDREDS of sex trafficking victims, lawyers say. Millionaire fashion tycoon Nygard, 77, is “cooperating” with the FBI after being hit by numerous sexual assault and harassment allegations – claims he denies. This month, ten women filed a class-action lawsuit accusing the alleged monster of using his Bahamas [820;]'), (0.06953352420612616, 'Prince Andrew interview – recap and reaction from the Newsnight special. PRINCE Andrew complained in Saturdays interview with Emily Maitlis of the BBCs Newsnight — filmed at Buckingham Palace — that the Epstein saga had become a constant sore for himself and his family. He said that he had no recollection of ever meeting Virginia Roberts Giuffre, who claims that as a teenager in 2001 she [820;]')], 'entities': [('820', 14), ('PRINCE ANDREW', 14), ('JEFFREY EPSTEIN', 13), ('FBI', 6), ('EPSTEIN', 6), ('ANDREW', 5), ('8211', 3), ('BAHAMAS', 3), ('US', 2), ('ANOUSKA DE GEORGIOU', 2)], 'nouns': [('EPSTEIN', 23), ('ANDREW', 22), ('PRINCE', 21), ('JEFFREY', 15), ('FBI', 6), ('YORK', 6), ('PAEDO', 5), ('DE', 5), ('NEW', 4), ('BILL', 4)]}, {'examples': [(0.09430066028155248, 'Kim Jong-un: North Korean leader rides horse up sacred mountain. Images of Kim Jong-un astride a white steed on Mount Paektu fuels speculation of a major announcement.'), (0.09430066028155248, 'Kim Jong-un: North Korean leader rides horse up sacred mountain. Images of Kim Jong-un astride a white steed on Mount Paektu fuel speculation of a major announcement.'), (0.09415524176867082, 'Kim Jong-un dead rumours resurface as Japan reveals it has ‘some suspicions’ about state of North Korean tyrant’s health. JAPAN has revealed it has “some suspicions” about the health of the periodically missing North Korean dictator Kim Jong-un.160;160; The country’s defence minister made the bombshell comment at a press briefing and added he thought recent movements in the secretive state were “all very strange”. Following his first disappearing act, reports emerged claiming the enigmatic [820;]'), (0.09415524176867082, 'Kim Jong-un dead rumours resurface as Japan reveals it has ‘some suspicions’ about state of North Korean tyrant’s health. JAPAN has revealed it has “some suspicions” about the health of the periodically missing North Korean dictator Kim Jong-un. The country’s defence minister made the bombshell comment at a press  ...
# examples_worst_performant [{'examples': [(0.021585712864943294, 'Australia wildfires: Dozens arrested for deliberately starting fires. Police take no-tolerance approach as bushfires destroy more than 2,000 homes'), (0.020983817857088267, 'Australian bushfires: Why do people start fires during fires?. As fires takes hold across vast areas of Australia, some people set out to make the problem worse.'), (0.018882134264496177, 'Australia wildfire: 12-year-old boy and his dog flee from deadly blaze in truck. Hundreds of fires continue to rage across the country as nation braces for heatwave'), (0.018709945352508063, "Australia wildfires: Half a billion animals and plants killed as glaciers turn black. 'There is such a big area now that is still on fire and still burning that we will probably never find the [animals'] bodies,' says ecologist"), (0.017829590000274072, 'One-in-100-year storms trigger flash flooding in Australia. Fire-ravaged country faces fresh misery amid escalating climate change emergency')], 'entities': [('AUSTRALIA', 62), ('AUSTRALIAN', 7), ('ONE', 7), ('TWO', 4), ('SATURDAY', 4), ('SUNDAY', 3), ('MILLIONS', 3), ('HUNDREDS', 3), ('THOUSANDS', 2), ('SOUTH AFRICA', 2)], 'nouns': [('AUSTRALIA', 62), ('SATURDAY', 4), ('SUNDAY', 3), ('SOUTH', 2), ('AFRICA', 2), ('TUESDAY', 2), ('MEGHAN', 2), ('MARKLE', 2), ('HARRY', 2), ('US', 2)]}, {'examples': [(0.003843705642131389, "New mum dies after doctor 'pulls uterus from body' when removing placenta. WARNING - GRAPHIC CONTENT: The 27-year-old doctor could face three years in jail over the death of of Alisa Tepikina, 22, who only had time to smile at her new daughter, Anya, before she died in Russia"), (0.003796939981346066, 'Trump says deal with China will be signed within days after gruelling trade war. The president has spent more than a year trying to negotiate the deal, and will likely present it as a signature achievement in an election year'), (0.003752247125006658, 'Necrophile monster bludgeoned couple and their baby to death with a rock then had sex with the mum’s corpse. A NECROPHILE bludgeoned a mum to death before having sex with her corpse and raping herten-year-old her ten-year-old daughter. The beast, named locally as Nasiruddin, 8, also murdered the dad and killed their baby with a rock after breaking into the family home in Azamgarh, India. He admitted the shocking assaults after armed cops arrested [820;]'), (0.0036095689231634234, "Rodney Reed: Death row inmates lawyers file new legal bid to halt execution scheduled in days. 'It is deeply disturbing that a consensual intimate relationship between Rodney Reed, a black man, and Stacey Stites, a white woman, was conflated with an act of violence,' says Amnesty International USA's senior criminal justice programmes officer"), (0.0035627670001797175, 'Chechen leader humiliates mother whose daughter died in suspected lockdown domestic abuse. Four-year-old daughter of 2-year-old woman who died says she was strangled and hurled down stairs')], 'entities': [('820', 112), ('US', 35), ('TWO', 35), ('THREE', 24), ('TRUMP', 21), ('CHINA', 20), ('FIRST', 19), ('AUSTRALIA', 19), ('NAVRATRI', 18), ('ONE', 14)], 'nouns': [('CORONAVIRUS', 39), ('US', 36), ('NAVRATRI', 32), ('AUSTRALIA', 24), ('CHINA', 20), ('TRUMP', 18), ('SYDNEY', 15), ('MEXICO', 15), ('ISRAEL', 12), ('HINDU', 12)]}, {'examples': [(0.004002769106110923, 'Coronavirus ravaged global economy will suffer ‘for years’ as OECD says bounce back is ‘wishful thinking’. THE global economy will take years to recover from the coronavirus pandemic, an international trade body warned today. Angel Gurría, head of OECD, said the economic shock was already bigger than the financial crisis of 2008 and the idea of a quick bounce-back was wishful thinking. ⚠️ Read our coronavirus live blog for the latest [820;]'), (0.0035945539862210973, 'Coronavirus kills Iranian supreme leader Ayatollah Khamenei’s top aide as deadly Covid-1 sweeps country. AN adviser to Irans supreme leader A ...
# examples_populous [{'examples': [(0.0012492872638355597, "Three-year-old girl dies after being thrown from 7th floor window. Detectives investigating why man committed 'such a horrific act', police spokesperson says"), (0.001216974909983106, "7-year-old woman accused of killing 82-year-old neighbour with brick. Victim found dead in back garden after being hit 'multiple times with brick,' police say"), (0.0011882595525671714, 'Man takes dead body to police station and says he killed three more people. Shankar is now facing four murder charges'), (0.0011543962792921034, 'The /11 disease that’s given men breast cancer and already killed 2,000 heroes – and the death toll is set to overtake those that died on the day. WHILE thousands were running away from the deadly smoke, terror and carnage that was /11 8211; they were rushing in. Some 75,000 firefighters, police officers, paramedics and rescuers risked their own lives to save others after the terror attack 18 years ago. In the following days, people from every state 8211; and almost every single [820;]'), (0.001136286045088438, "Man kills 12-year-old sister in sacrifice to goddess of war, police say. Indian officials say they have recovered young girl's headless body from forest")], 'entities': [('US', 217), ('820', 91), ('TWO', 78), ('ONE', 64), ('FOUR', 51), ('THREE', 48), ('RUSSIAN', 40), ('INDIAN', 39), ('FIRST', 38), ('CHINESE', 38)], 'nouns': [('US', 217), ('KENYA', 18), ('UN', 13), ('M', 6), ('£', 6), ('CO2', 5), ('F-16', 4), ('AFRICA', 4), ('VINT', 4), ('CERF', 4)]}, {'examples': [(0.003102551827364351, 'British woman, 2, missing for over a week in Fiji after family says she stopped sending daily message. A BRITISH woman has gone missing in the south Pacific island of Fiji. Lydia OSullivan, from Whitehaven, Cumbria has not ben seen or heard from for the past eight days, Cumbria Police said. The 2-year-old has been travelling for the past two years and had been living and working in Auckland, New Zealand. Lydia is [820;]'), (0.0029171425622587298, 'Sick pair who slaughtered pregnant teen because they ‘wanted to see someone die’ are jailed. TWO friends brutally killed a pregnant teenage girl because they wanted to see someone die, a court in Germany has heard. Niko Goettlich, 21, has been jailed for life and 1-year-old Nicolas Knoop sent to a psychiatric hospital for the brutal killing, in which the victim was stabbed 0 times. The 18-year-old victim, named only [820;]'), (0.002877562905900477, 'Hero boy, 15, died saving his sister, 5, in violent struggle with ‘druggie burglar’ who broke into their home. A HEROIC schoolboy died saving his five-year-old sister during a violent burglary at the family home, cops have revealed. Khyler Edman, 15, was looking after the young girl in Port Charlotte, Florida, when police say his home was raided by an ex con. When cops arrived they found 27-year-old suspect Ryan Cole nearby with stab [820;]'), (0.002876623922002317, 'World’s oldest woman Jeanne Calment, 122, may have been a HOAX and could really have been her -year-old daughter. A WOMAN long believed to be the oldest ever may really have been her -year-old daughter out to fool the world. Frenchwoman Jeanne Calment made global headlines when she apparently died in 17 aged an incredible 122 years and 164 days. However one Russian academic says the woman who was buried was actually her daughter [820;]'), (0.0028283337718360804, 'Man who wrongly thought he had coronavirus kills himself to protect his family. Named as 50-year-old Balakrishnayya, the man feared he would pass on the virus to his family and to those living in the village of Srikalahasti in the Indian state of Andhra Pradesh')], 'entities': [('820', 176), ('AUSTRALIA', 75), ('TWO', 61), ('US', 56), ('FIRST', 34), ('ONE', 31), ('TRUMP', 29), ('THREE', 26), ('FOUR', 20), ('8211', 17)], 'nouns': [('AUSTRALIA', 77), ('US', 59), ('CORONAVIRUS', 47), ('SOUTH', 19), ('TRUMP', 19), ('NEW', 17), ('PRESIDENT', 14), ('FRANCE', 12), ('B ...

# %% [raw]
# from importlib import reload
# reload(reporter)
# net2p_stats, net2p_coherences, net2p_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_louvain_2lim_permissive.csv")
#
# for key, value in net2p_stats.items():
#     if "examples" not in key:
#         print (key, value)

# %% [raw]
# from importlib import reload
# reload(reporter)
# net2t_stats, net2t_coherences, net2t_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_louvain_2lim_tight.csv")
#
# for key, value in net2t_stats.items():
#     if "examples" not in key:
#         print (key, value)

# %% [raw]
# from importlib import reload
# reload(reporter)
# net2h_stats, net2h_coherences, net2h_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_louvain_2lim_highres.csv")
#
# for key, value in net2h_stats.items():
#     if "examples" not in key:
#         print (key, value)

# %% [markdown]
# ## KEY MODEL

# %%
from importlib import reload
reload(reporter)
net2h_stats, net2h_coherences, net2h_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_louvain_2lim_permissive_highres.csv")

for key, value in net2h_stats.items():
    if "examples" not in key:
        print (key, value)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# c_v 0.6359
# c_npmi 0.0974
# macro_time_coherence 2047209.5042250515
# micro_time_coherence 360888.95876903896
# Average document word count 39.23135730895422
# Number of documents 31393
# Latest record Fri, 01 May 2020 00:18:25 GMT
# Earliest record Wed, 9 Oct 2019 21:52:38 +0000
# Number of clusters 625
# Median cluster size 7.0
# Percent clustered docs 51.8

# %%
# Formatted best examples
example_df = reporter.format_examples(net2h_stats['examples_best_performant'][3])
example_df.to_csv("outputs/RSS_net2h_best.csv", index=False)
example_df
# Out:
#    TextRank Score                                               Text  \
# 0        0.172362  Chinese team kicked out of its own Military Wo...
# 1        0.172174  Chinese team kicked out of its own Military Wo...
# 2        0.133699  Chow Chow puppies are the spitting-image of pa...
# 3        0.133554  Pets in China forced to wear bizarre makeshift...
#
#       Entities  Entities Count
# 0      CHINESE               5
# 1        CHINA               4
# 2  WORLD GAMES               4
# 3       SECOND               4

# %%
# Formatted populous examples
example_df = reporter.format_examples(net2h_stats['examples_populous'][0])
example_df.to_csv("outputs/RSS_net2h_pop.csv", index=False)
example_df
# Out:
#    TextRank Score                                               Text  \
# 0        0.000569  Ivanka Trump contradicts father Donald by sayi...
# 1        0.000552  Good bloodlines! Trump praises Henry Ford, mot...
# 2        0.000538  Democrat congresswoman says notorious LA gangs...
# 3        0.000524  Coronavirus: Kudlow claims White House is guid...
#
#        Entities  Entities Count
# 0         TRUMP            1599
# 1            US            1154
# 2  DONALD TRUMP             648
# 3          IRAN             352

# %%
for key, value in net2h_stats.items():
    if "examples" in key:
        print (key, value)
# Out:
# examples_best_performant [{'examples': [(0.20201540962590783, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the holiday celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Here is what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving []'), (0.20201540962590783, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish holiday that begins five days after Yom Kippur. So what is being celebrated? Here is what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving []'), (0.20113741175101518, 'Sukkot 1: What’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Heres what you need to know What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []'), (0.20113741175101518, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Heres what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []'), (0.19369435724615386, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the holiday celebrated?. SUKKOT is a weeklong Jewish holiday that comes five days after Yom Kippur. So what is being celebrated? Heres what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []')], 'entities': [('JEWISH', 15), ('SUKKOT', 13), ('FIVE DAYS', 5), ('YOM KIPPUR', 5), ('THE 4 YEARS', 5), ('ISRAELIS', 5), ('SUKKOT 1', 4)], 'nouns': [('SUKKOT', 19), ('FEAST', 5), ('TABERNACLES', 5), ('YOM', 5), ('KIPPUR', 5), ('ISRAELIS', 5)]}, {'examples': [(0.09632116118478755, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. Here, we take a closer look at the festival and its origin, as today marks the final day of Ashura. What is the Day of Ashura? Ashura marks the []'), (0.09597833522955408, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. Heres when the festival is this year, how its celebrated by Sunni and Shia Muslims and whether it requires participants to fast. What is the Day of Ashura? Ashura []'), (0.09527412733165404, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. We take a closer look at the festival and its origin, as today marks the final day of Ashura. What is the Day of Ashura? Ashura marks the day []'), (0.08194350353313885, 'Ashura 1 – what is the Day of Ashura, do you have to fast and what is the Ziyarat Ashura prayer?. ASHURA is a festival of remembrance in Islam 11 but Sunni and Shia Muslims celebrate it for different reasons. Here ...
# examples_worst_performant [{'examples': [(0.07328293988454009, 'Remembrance Day quotes, poems and messages to remember the fallen. ON Remembrance Day we remember the soldiers who fought for Britain during the First World War and World War II. Armistice Day is commemorated every year on November 11. Here are some of the most powerful Remembrance Day poems and messages penned in memory of the fallen. For the Fallen Penned by Laurence Binyon, this []'), (0.06945034441314296, 'Final days of Nazi Germany revealed in shocking photos as world remembers Hitler’s defeat on VE Day. THE final days of Nazi Germany are revealed in a series of shocking photos as the world remembers Hitler’s defeat on VE Day. Today commemorates a milestone 75 years since the end of World War II and the date remains a special time in UKs history. Victory in Europe officially took place on this day []'), (0.0693693465214002, 'Remembrance Day poems, quotes and messages to remember the fallen. ON Remembrance Day we remember the soldiers who fought for Britain during World Wars I and II. Armistice Day is commemorated every year on November 11. Here are some of the most powerful Remembrance Day poems and messages penned in memory of the fallen. For the Fallen Penned by Laurence Binyon, this is probably the []'), (0.06318422637903612, "Last Nazi Decoded Communication Intercepted by Bletchley Park Revealed on VE Day. During World War II, a mansion in England's Bletchley Park became the nation's centre for deciphering Nazi coded messages. The work done there was kept secret not only during the war, but for many years after."), (0.05568096235345043, 'Battle of Midway: World War Two Japanese carrier wrecks found. Both ships were sunk during the Battle of Midway, fought between Japan and the US in 14.')], 'entities': [('WORLD WAR II', 11), ('REMEMBRANCE DAY', 6), ('US', 4), ('GERMANY', 4), ('HITLER', 3), ('WORLD WAR', 3), ('NAZI', 3), ('VE DAY', 3), ('FRENCH', 2), ('SENATE', 2)], 'nouns': [('WORLD', 22), ('WAR', 19), ('II', 13), ('DAY', 11), ('REMEMBRANCE', 6), ('BATTLE', 4), ('GERMANY', 4), ('NAZI', 4), ('HITLER', 3), ('US', 3)]}, {'examples': [(0.07221192959801977, 'Clinton: \'Every UK voter deserves to see Russia report\'. Hillary Clinton says she\'s "dumbfounded" that a report on Russian influence in the UK has not been released.'), (0.06853517256053984, "Mysterious plane crash that killed former secretary general may have been external attack, United Nations says. UK, US, South Africa and Russia all accused of withholding information about downing of Dag Hammarskjold's aircraft during peace mission to Cold War torn Congo"), (0.06758442585981762, "Hillary Clinton: 'Shameful' not to publish Russia report. A report on alleged Russian interference in the UK should come out, says the former US presidential candidate."), (0.06746001893858089, "General election 1: Reddit says UK-US trade talks document leak 'linked to Russia'. The papers had their first wide burst of attention when unveiled in the election campaign by Labour."), (0.06661430988122365, 'Russia spy case: Is Paul Whelan a hostage of Russia or a spy?. The British family of a man accused of spying in Moscow has called on the UK government to do more to secure his release.')], 'entities': [('RUSSIA', 15), ('UK', 12), ('US', 7), ('RUSSIAN', 5), ('BLUE WHALE', 4), ('NOVICHOK', 3), ('SOVIET', 3), ('POLAND', 2), ('UNITED NATIONS', 2), ('SOUTH AFRICA', 2)], 'nouns': [('RUSSIA', 15), ('UK', 12), ('US', 7), ('NOVICHOK', 4), ('BLUE', 4), ('WHALE', 4), ('COLD', 3), ('WAR', 3), ('CLINTON', 3), ('SOVIET', 3)]}, {'examples': [(0.17465731019000558, "Man's 'croissant-like' toenails had 'worst fungus ever seen' and needed sanding. WARNING - GRAPHIC IMAGES: David, from New Jersey, developed a foot and nail fungus five years ago and says the condition left him unable to walk properly"), (0.17344141468467209, 'Man, 6, left with knife sticking out of head after helping woman in the street. WARNING - GRAPHIC IMAGES: The 6-year-old  ...
# examples_populous [{'examples': [(0.0005693307449285833, "Ivanka Trump contradicts father Donald by saying whistleblower identity not particularly relevant. President's daughter also compares father to Abraham Lincoln"), (0.0005517350758823085, "Good bloodlines! Trump praises Henry Ford, motor pioneer whose antisemitism was admired by Hitler. President had already praised auto-maker in 1 after embracing 'King of Israel' title"), (0.0005375824925026383, 'Democrat congresswoman says notorious LA gangs have more integrity than Donald Trump. Maxine Waters compares president to the Crips and Bloods'), (0.000523730626348378, "Coronavirus: Kudlow claims White House is guided by the facts as Trump gambles on unproven drug. 'I'd bet on President Trump's intuition on this one,' says a White House trade adviser in shot at other coronavirus task force members"), (0.0005212814833350948, "Trump says Mexico has big coronavirus problems despite US having three times as many deaths as Mexican Covid-1 cases. Donald Trump said California was lucky to have him as president, whilst citing Mexico's coronavirus problems")], 'entities': [('TRUMP', 1599), ('US', 1154), ('DONALD TRUMP', 648), ('IRAN', 352), ('WHITE HOUSE', 315), ('DEMOCRATS', 195), ('UKRAINE', 193), ('SYRIA', 180), ('TRUMPS', 178), ('JOE BIDEN', 175)], 'nouns': [('TRUMP', 2300), ('US', 1221), ('CORONAVIRUS', 1110), ('PRESIDENT', 966), ('DONALD', 697), ('HOUSE', 557), ('WHITE', 415), ('IRAN', 378), ('BIDEN', 283), ('TRUMPS', 256)]}, {'examples': [(0.00064963029578354, 'Coronavirus lockdown in Italy causes terrified Brits to blast chaotic hospitals for putting healthy people at risk. TERRIFIED Brits caught in the Italian coronavirus lockdown have spoken of their fear as panic gripped the country. Fourteen people have died and more than 5 have been diagnosed with COVID-1 in Italy, which has the third largest number of coronavirus cases after China and South Korea. Read our coronavirus live blog for all the []'), (0.0006392427755773374, 'Coronavirus: Italy death toll soars by 1 with 1,5 new cases in a DAY as 16million people put in quarantine. ITALY has quarantined 16 MILLION people in drastic measures to stop the deadly spread of coronavirus as the country becomes the second-worst affected in the WORLD. More than a quarter of the population has been put into lockdown as deaths in the country rose by 1 in a single day. ⚠️ Read our coronavirus live blog for []'), (0.0006336582434298568, 'Italy coronavirus death toll overtakes China as another 47 die in one day taking total to 45. ITALY has overtaken China for the number of coronavirus deaths after 47 more died from the disease. The country has now seen ,45 people die from the coronavirus, which began in the Chinese city of Wuhan. ⚠️ Read our coronavirus live blog for the latest news  updates Some ,45 people have died in China []'), (0.0006293927159573601, 'Coronavirus map: How many deaths have there been from Covid-1 so far?. CORONAVIRUS has surged across the globe like wildfire with scores of new cases recorded daily, as infections rapidly rip across the globe. Here are the locations that the virulent bugs deadly tentacles have spread to. ⚠️ Read our coronavirus live blog for the latest news  updates Which countries have the most cases of coronavirus? []'), (0.000629116371488819, 'Spain’s coronavirus death toll soars by record 4 in a day to ,1 as deadly outbreak races out of control. CORONAVIRUS has claimed the lives of 4 people in Spain in 4 hours setting a disturbing new record. The country has a death toll of ,1 making it the second-worst hit in the world behind Italy. ⚠️ Read our coronavirus live blog for the latest news  updates And the daily number of people dying []')], 'entities': [('UK', 682), ('CORONAVIRUS', 449), ('CHINA', 428), ('ITALY', 408), ('SPAIN', 281), ('1', 276), ('FIRST', 254), ('WUHAN', 248), ('EUROPE', 217), ('US', 207)], 'nouns': [('CORONAVIRUS', 3590), ('UK', 727), ('LIVE', 564), ('CHINA', 447), ('ITALY', 416), ('W ...

# %% [markdown]
# ## KEY MODEL

# %%
from importlib import reload
reload(reporter)
net3_stats, net3_coherences, net3_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_louvain_3lim_5000.csv")

for key, value in net3_stats.items():
    if "examples" not in key:
        print (key, value)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# c_v 0.6704
# c_npmi 0.1274
# macro_time_coherence 1237536.548704626
# micro_time_coherence 59190.87811567828
# Average document word count 39.23135730895422
# Number of documents 31393
# Latest record Fri, 01 May 2020 00:18:25 GMT
# Earliest record Wed, 9 Oct 2019 21:52:38 +0000
# Number of clusters 128
# Median cluster size 8.0
# Percent clustered docs 15.7

# %%
# Formatted best examples
example_df = reporter.format_examples(net3_stats['examples_best_performant'][2])
example_df.to_csv("outputs/RSS_net3_best.csv", index=False)
example_df
# Out:
#    TextRank Score                                               Text  \
# 0        0.103767  How to say Happy Eid for al-Fitr in . MUSLIMS ...
# 1        0.103767  How to say Happy Eid for al-Fitr in . MUSLIMS ...
# 2        0.100323  When will Eid al-Fitr start in  and what is th...
# 3        0.098397  Differences between Eid al-Fitr and Eid al-Adh...
#
#       Entities  Entities Count
# 0  EID AL-FITR              22
# 1      MUSLIMS               9
# 2      ISLAMIC               5
# 3  EID AL-ADHA               4

# %%
# Formatted populous examples
example_df = reporter.format_examples(net3_stats['examples_populous'][0])
example_df.to_csv("outputs/RSS_net3_pop.csv", index=False)
example_df
# Out:
#    TextRank Score                                               Text  \
# 0        0.002791  UK Prime Minister Boris Johnson to Unveil ‘Roo...
# 1        0.002676  Coronavirus UK news LIVE: Boris Johnson admits...
# 2        0.002638  Boris Johnson Unveils Plan to Lift Coronavirus...
# 3        0.002636  Boris Johnson Opens Up on His Struggle Against...
#
#         Entities  Entities Count
# 0             UK             461
# 1  BORIS JOHNSON             185
# 2          CHINA              99
# 3        BRITAIN              87

# %%
for key, value in net3_stats.items():
    if "examples" in key:
        print (key, value)
# Out:
# examples_best_performant [{'examples': [(0.20201540962590783, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the holiday celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Here is what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving []'), (0.20201540962590783, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish holiday that begins five days after Yom Kippur. So what is being celebrated? Here is what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving []'), (0.20113741175101518, 'Sukkot 1: What’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Heres what you need to know What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []'), (0.20113741175101518, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Heres what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []'), (0.19369435724615386, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the holiday celebrated?. SUKKOT is a weeklong Jewish holiday that comes five days after Yom Kippur. So what is being celebrated? Heres what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []')], 'entities': [('JEWISH', 15), ('SUKKOT', 13), ('FIVE DAYS', 5), ('YOM KIPPUR', 5), ('THE 4 YEARS', 5), ('ISRAELIS', 5), ('SUKKOT 1', 4)], 'nouns': [('SUKKOT', 19), ('FEAST', 5), ('TABERNACLES', 5), ('YOM', 5), ('KIPPUR', 5), ('ISRAELIS', 5)]}, {'examples': [(0.10532475101799392, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. Heres when the festival is this year, how its celebrated by Sunni and Shia Muslims and whether it requires participants to fast. What is the Day of Ashura? Ashura []'), (0.10401645890653997, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. Here, we take a closer look at the festival and its origin, as today marks the final day of Ashura. What is the Day of Ashura? Ashura marks the []'), (0.10331176200458986, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. We take a closer look at the festival and its origin, as today marks the final day of Ashura. What is the Day of Ashura? Ashura marks the day []'), (0.09234541009005921, 'Ashura 1 – what is the Day of Ashura, do you have to fast and what is the Ziyarat Ashura prayer?. ASHURA is a festival of remembrance in Islam 11 but Sunni and Shia Muslims celebrate it for different reasons. Here ...
# examples_worst_performant [{'examples': [(0.002790855607339681, 'UK Prime Minister Boris Johnson to Unveil ‘Rooseveltian New Deal’ to Reboot Post-COVID-1 Economy. Ahead of his widely-anticipated speech to map out plans for kick-starting the economy, UK Prime Minister Boris Johnson said on Monday his government will "not go back to the austerity of 1 years ago", vowing that the country would "bounce back" from the coronavirus pandemic.'), (0.002676375105440803, 'Coronavirus UK news LIVE: Boris Johnson admits the UK faces ‘challenge’ as Covid-1 cases rise to . THE Prime Minister has said cases in the UK could rise significantly as he warned the UK faces a challenge amid rising coronavirus cases. Boris Johnson told the BBC the possibility of further transmission of the deadly virus was clearly on the cards. Coronavirus has now infected in the UK and Covid-1 is now []'), (0.002638220873613075, 'Boris Johnson Unveils Plan to Lift Coronavirus Lockdown in UK, Faces Criticism From Labour Leader. Despite taking measures to prevent the spread of the coronavirus infection, the UK has still registered 1,1 confirmed cases of COVID-1 and 1,55 deaths from the novel disease.'), (0.002635839153826081, "Boris Johnson Opens Up on His Struggle Against COVID-1, ‘Contingency Plans' in Case of His Death. As the coronavirus pandemic spread across the UK, the country’s Prime Minister Boris Johnson had been diagnosed with the respiratory disease on 6 March and was admitted to hospital 1 days later, with the illness eventually landing him in intensive care."), (0.0026253745049024794, "COVID-1: UK Prime Minister Boris Johnson's Lockdown Reduction Plan Explained. The UK government has released a 5-page strategy document, dubbed ‘Our Plan to Rebuild’, which outlines a broad program for the eventual roll-back of coronavirus lockdown measures.")], 'entities': [('UK', 461), ('BORIS JOHNSON', 185), ('CHINA', 99), ('BRITAIN', 87), ('EU', 74), ('BRITISH', 67), ('CORONAVIRUS', 62), ('LONDON', 58), ('BREXIT', 57), ('FIRST', 55)], 'nouns': [('CORONAVIRUS', 515), ('UK', 508), ('JOHNSON', 235), ('BORIS', 211), ('MINISTER', 150), ('COVID-1', 149), ('PRIME', 132), ('CHINA', 105), ('BRITAIN', 91), ('EU', 85)]}, {'examples': [(0.2165821606540047, "Police Presence in Central Glasgow Following Lethal Stabbing Attack - Video. During the incident on Friday, a man stabbed two people to death and injured six before being shot by Scottish police. The authorities are investigating the attack, stressing it is not being treated as a terrorist act - unlike last week's assault in Reading, committed by a 5-year-old refugee from Libya, known to the security services."), (0.1996364198019446, "'I Was Trying to Compress Maintenance Guy's Wound': Witness Details Hotel Stabbing in Glasgow. The police have indicated that they are continuing their investigation into the incident, however, they added that it is not being treated as a terrorist act. It comes five days after 5-year-old Khairi Saadallah, who came to the United Kingdom from Libya, stabbed to death three people in a park in Reading."), (0.19920351140548098, 'Glasgow Attacker Was Allegedly Sudanese National Who Threatened to Stab People, Reports Say. Six people, including one police officer, were injured in Glasgow, Scotland, in a knife attack, Assistant Chief Constable Steve Johnson said on 6 June. The police don’t consider the stabbing a terrorist attack.'), (0.198214796435325, 'UK City of Reading Day After Stabbing Incident - Video. Three people died, and another three suffered injuries, after a man launched an attack with a knife in the UK city of Reading.'), (0.18636311170324502, 'Are Poor Conditions in Glasgow’s COVID-1 Hotels for Asylum Seekers to Blame for Knife Attack?. On Friday, a Sudanese man went on a stabbing spree in a Glasgow hotel hosting asylum seekers. Experts believe the city has been flooded with people fleeing conflict-torn countries as a result of Western military campaigns. The UK has emerged as a top destin ...
# examples_populous [{'examples': [(0.002790855607339681, 'UK Prime Minister Boris Johnson to Unveil ‘Rooseveltian New Deal’ to Reboot Post-COVID-1 Economy. Ahead of his widely-anticipated speech to map out plans for kick-starting the economy, UK Prime Minister Boris Johnson said on Monday his government will "not go back to the austerity of 1 years ago", vowing that the country would "bounce back" from the coronavirus pandemic.'), (0.002676375105440803, 'Coronavirus UK news LIVE: Boris Johnson admits the UK faces ‘challenge’ as Covid-1 cases rise to . THE Prime Minister has said cases in the UK could rise significantly as he warned the UK faces a challenge amid rising coronavirus cases. Boris Johnson told the BBC the possibility of further transmission of the deadly virus was clearly on the cards. Coronavirus has now infected in the UK and Covid-1 is now []'), (0.002638220873613075, 'Boris Johnson Unveils Plan to Lift Coronavirus Lockdown in UK, Faces Criticism From Labour Leader. Despite taking measures to prevent the spread of the coronavirus infection, the UK has still registered 1,1 confirmed cases of COVID-1 and 1,55 deaths from the novel disease.'), (0.002635839153826081, "Boris Johnson Opens Up on His Struggle Against COVID-1, ‘Contingency Plans' in Case of His Death. As the coronavirus pandemic spread across the UK, the country’s Prime Minister Boris Johnson had been diagnosed with the respiratory disease on 6 March and was admitted to hospital 1 days later, with the illness eventually landing him in intensive care."), (0.0026253745049024794, "COVID-1: UK Prime Minister Boris Johnson's Lockdown Reduction Plan Explained. The UK government has released a 5-page strategy document, dubbed ‘Our Plan to Rebuild’, which outlines a broad program for the eventual roll-back of coronavirus lockdown measures.")], 'entities': [('UK', 461), ('BORIS JOHNSON', 185), ('CHINA', 99), ('BRITAIN', 87), ('EU', 74), ('BRITISH', 67), ('CORONAVIRUS', 62), ('LONDON', 58), ('BREXIT', 57), ('FIRST', 55)], 'nouns': [('CORONAVIRUS', 515), ('UK', 508), ('JOHNSON', 235), ('BORIS', 211), ('MINISTER', 150), ('COVID-1', 149), ('PRIME', 132), ('CHINA', 105), ('BRITAIN', 91), ('EU', 85)]}, {'examples': [(0.004299720165511591, 'Why did Donald Trump kill Iran’s general Qasem Soleimani?. AIRSTRIKES approved by President Donald Trump killed Irans top General Qasem Soleimani while he was in Iraq 11 causing tensions to reach boiling point. But why did Donald Trump kill Soleimani? Why did Donald Trump kill Irans general Qasem Soleimani? Donald Trump wanted to kill Irans general Qasem Soleimani because he claims Soleimani had killed []'), (0.004108348441848528, 'World War fears as Iran’s new top general warns US ‘our missile power is unstoppable’ and ‘we are not afraid of war’. A TOP Iranian military leader who taunted Donald Trump over the sickening /11 attacks has warned the US his missiles are unstoppable. The chilling threat from General Hossein Salami emerged just 4 hours after the USs execution of the head of Irans feared Quds force, Qasem Soleimani 11 whom Salami is expected to replace. Soleimani []'), (0.004081122954660644, 'Donald Trump claims victory as Iran ‘stands down’ warns its ‘campaign of terror’ is over after revenge missile strike. DONALD Trump pulled back from the brink of a new Gulf war last night after Iran launched a fake revenge missile blitz. The US President ruled out a further tit-for-tat response after no US, British or coalition partner deaths were reported from a flimsy “face-saving” attack on two military bases in Iraq. He warned Iran []'), (0.004048930779645652, 'Iran’s president warns Western troops ‘may be in danger’ in chilling new threat to US and Britain over nuke deal. IRAN’s president threatened Western troops today saying they are “not safe” in the Middle East. Tensions have reached boiling point since the US killed top Iranian general Qasem Soleimani in a drone strike two weeks ago, with Tehran firing missiles back at Americ ...

# %%
from importlib import reload
reload(reporter)
netlp_stats, netlp_coherences, netlp_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_lp_3lim_5000.csv")

for key, value in netlp_stats.items():
    if "examples" not in key:
        print (key, value)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# c_v 0.6551
# c_npmi 0.1218
# macro_time_coherence 1443531.3941189076
# micro_time_coherence 139909.30824108035
# Average document word count 39.23135730895422
# Number of documents 31393
# Latest record Fri, 01 May 2020 00:18:25 GMT
# Earliest record Wed, 9 Oct 2019 21:52:38 +0000
# Number of clusters 373
# Median cluster size 7.0
# Percent clustered docs 14.0

# %%
for key, value in netlp_stats.items():
    if "examples" in key:
        print (key, value)
# Out:
# examples_best_performant [{'examples': [(0.20201540962590783, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the holiday celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Here is what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving []'), (0.20201540962590783, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish holiday that begins five days after Yom Kippur. So what is being celebrated? Here is what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving []'), (0.20113741175101518, 'Sukkot 1: What’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Heres what you need to know What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []'), (0.20113741175101518, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the festival celebrated?. SUKKOT is a weeklong Jewish festival that begins five days after Yom Kippur. So what is being celebrated? Heres what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []'), (0.19369435724615386, 'Sukkot 1 – what’s the Jewish Feast of Tabernacles and how is the holiday celebrated?. SUKKOT is a weeklong Jewish holiday that comes five days after Yom Kippur. So what is being celebrated? Heres what you need to know. What is Sukkot? Sukkot is a Jewish holiday which is all about giving thanks for the autumn harvest and commemorating the 4 years Israelis spent wandering the desert after leaving slavery []')], 'entities': [('JEWISH', 15), ('SUKKOT', 13), ('FIVE DAYS', 5), ('YOM KIPPUR', 5), ('THE 4 YEARS', 5), ('ISRAELIS', 5), ('SUKKOT 1', 4)], 'nouns': [('SUKKOT', 19), ('FEAST', 5), ('TABERNACLES', 5), ('YOM', 5), ('KIPPUR', 5), ('ISRAELIS', 5)]}, {'examples': [(0.14245268922841536, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. Heres when the festival is this year, how its celebrated by Sunni and Shia Muslims and whether it requires participants to fast. What is the Day of Ashura? Ashura []'), (0.142054320783277, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. Here, we take a closer look at the festival and its origin, as today marks the final day of Ashura. What is the Day of Ashura? Ashura marks the []'), (0.140749732813062, 'Ashura 1 – what is the Day of Ashura, do you have to fast for two days and what is the Ziyarat Ashura prayer?. THE Day of Ashura is a holy festival of remembrance in Islam, dating back 1, years to events that followed the death of the Prophet Muhammad. We take a closer look at the festival and its origin, as today marks the final day of Ashura. What is the Day of Ashura? Ashura marks the day []'), (0.1255614833147088, 'Ashura 1 – what is the Day of Ashura, do you have to fast and what is the Ziyarat Ashura prayer?. ASHURA is a festival of remembrance in Islam 11 but Sunni and Shia Muslims celebrate it for different reasons. Heres whe ...
# examples_worst_performant [{'examples': [(0.17969064071163734, 'Coronavirus: New York governor cant imagine Trump would fire top health expert Dr Fauci. The president sparks speculation after retweeting a comment stating Dr Anthony Fauci should be fired'), (0.17195474422087845, 'Trump says coronavirus has passed peak as US could reopen in coming weeks. As an amended New York death toll passed 1, on Wednesday, president Trump suggested some states could reopen soon'), (0.16884710147644946, "Trump says coronavirus really working out as troops dispatched in New York. 'We're prepared, and we're doing a great job with it'"), (0.16725238272851795, "Video emerges of George HW Bush calling top health official who has contradicted Trump a hero. Dr Anthony Fauci says he doesn't want to 'embarrass' president after repeatedly correcting claims"), (0.15628992931153837, 'Coronavirus: New York funeral home puts corpses in lorries. Police were called on Wednesday after the home in Brooklyn put dozens of bodies in rented trucks.')], 'entities': [('TRUMP', 6), ('NEW YORK', 5), ('CORONAVIRUS', 3), ('ANTHONY FAUCI', 2), ('WEDNESDAY', 2), ('GEORGE HW BUSH', 1), ('US', 1), ('COMING WEEKS', 1), ('1', 1), ('BROOKLYN', 1)], 'nouns': [('TRUMP', 6), ('CORONAVIRUS', 5), ('NEW', 5), ('YORK', 5), ('DR', 3), ('FAUCI', 3), ('ANTHONY', 2), ('WEDNESDAY', 2), ('GEORGE', 1), ('HW', 1)]}, {'examples': [(0.24436410384663046, 'Coronavirus: Belarus WW parade defies pandemic and upstages Putin. Belarus goes ahead with a Victory Day parade, but in Russia coronavirus forced its cancellation.'), (0.24436410384663043, 'Coronavirus: Belarus WW parade defies pandemic and upstages Putin. Belarus goes ahead with a Victory Day parade but in Russia coronavirus forced its cancellation.'), (0.19524206851197332, 'Russia WW parade goes ahead despite coronavirus fears. President Vladimir Putin said the parade could go ahead as coronavirus had retreated in the country.'), (0.16049198758638655, 'Coronavirus: Why are football teams in Belarus still playing?. Football and life, continue (almost) as normal in Belarus, but anxiety about coronavirus is growing.'), (0.15553773620837882, 'Coronavirus: Putin admits PPE shortage as lockdown extended. The president warns that the peak of the infection rate has not yet been reached in Russia.')], 'entities': [('BELARUS', 4), ('RUSSIA', 4), ('PUTIN', 3), ('PPE', 1), ('VICTORY DAY PARADE', 1), ('VICTORY DAY', 1), ('VLADIMIR PUTIN', 1)], 'nouns': [('CORONAVIRUS', 9), ('BELARUS', 6), ('PUTIN', 4), ('RUSSIA', 4), ('WW', 3), ('VICTORY', 2), ('DAY', 2), ('PPE', 1), ('PRESIDENT', 1), ('VLADIMIR', 1)]}, {'examples': [(0.06294451437667693, 'Europe is new coronavirus epicentre and has more cases a day than China at its peak, WHO warns. THE World Health Organisation has said Europe is now the epicentre of the global coronavirus pandemic. Dr Tedros Adhanom Ghebreyesus, the WHO Chief, said that the number of deaths surpassing 5, was a tragic milestone and that it is impossible to predict the peak of the deadly virus. The WHO chief told reporters in Geneva []'), (0.06230785175937195, 'What is a pandemic and what does it mean for coronavirus?. CORONAVIRUS has been declared a pandemic by the World Health Organisation (WHO). With the total number of cases passing 16, and the global death toll standing at over 4,6 11 WHO chief Dr Tedros Adhanom Ghebreyesus said they were now using the term because of concern over alarming levels of inaction regarding coronavirus. ⚠️ Read []'), (0.06165787379806406, 'World suffers worst day for coronavirus so far with 16, new infections just yesterday alone. THE world suffered the worst day yet for coronavirus infection after 16, new cases were recorded yesterday, the World Health Organisation said. Tedros Adhanom Ghebreyesus, chief of the UN health agency, also expressed concern for poorer countries as richer nations emerged from their lockdowns. He said: “We still have a long way to go in []'), (0.058663703872858575, 'Worst of c ...
# examples_populous [{'examples': [(0.00672611509883458, 'Prime Minister Johnson is Engaging with Clinical Team - UK Finance Minister. Last week, UK Prime Minister Boris Johnson was hospitalised after his COVID-1 symptoms grew more persistent.'), (0.006523029466808105, 'Coronavirus: Boris Johnson nurse \'Jenny from New Zealand\' on treating PM. Nurse Jenny McGee speaks of her "shock" at being singled out for praise by the UK prime minster.'), (0.006523029466808105, 'Coronavirus: Boris Johnson nurse \'Jenny from New Zealand\' on treating PM. Jenny McGee speaks of her "shock" at being singled out for praise by the UK prime minster.'), (0.006334812904239158, 'Outside View of Hospital Where Boris Johnson is Undergoing COVID-1 Treatment - Video. UK Prime Minister Boris Johnson, who announced in March that he had contracted the coronavirus, is now in an intensive care unit in London. British Foreign Secretary Dominic Raab is temporarily stepping in for Johnson until the prime minister gets better.'), (0.006168364541914637, 'UK Prime Minister Boris Johnson to Unveil ‘Rooseveltian New Deal’ to Reboot Post-COVID-1 Economy. Ahead of his widely-anticipated speech to map out plans for kick-starting the economy, UK Prime Minister Boris Johnson said on Monday his government will "not go back to the austerity of 1 years ago", vowing that the country would "bounce back" from the coronavirus pandemic.')], 'entities': [('UK', 218), ('BORIS JOHNSON', 184), ('EU', 42), ('BREXIT', 41), ('BRITISH', 41), ('BRITAIN', 35), ('LONDON', 25), ('CHINA', 24), ('FIRST', 22), ('JOHNSON', 21)], 'nouns': [('UK', 237), ('JOHNSON', 225), ('BORIS', 207), ('CORONAVIRUS', 144), ('MINISTER', 124), ('PRIME', 116), ('COVID-1', 69), ('BREXIT', 53), ('EU', 48), ('BRITAIN', 37)]}, {'examples': [(0.008761028181374041, "Hope Hicks returning to White House as counsellor to Trump. 'There is no one more devoted to implementing President Trump's agenda'"), (0.008366393751146513, 'President Cuomo: How New Yorks governor emerged as a leader in the coronavirus pandemic while Trump fumbled. Analysis: Governor receives widespread praise for response to Covid-1 outbreak while walking a fine line with a mercurial White House administration'), (0.008307464295947796, "Coronavirus: Trump says New York really in trouble but will be fine after 1 die in one day. President says state has 'more than enough' ventilators after governor slams claims as 'incorrect and grossly uninformed'"), (0.008129996293039125, "Coronavirus is Trumps Churchill moment and will seal his re-election, says former aide Steve Bannon. Ex-White House strategist claims president will 'bring country together' amid outbreak fears"), (0.0080795791533389, 'Trump news - live: President says police chokeholds sound so innocent and so perfect as Fauci warns against rallies over coronavirus risk. Follow the latest updates from the Trump administration')], 'entities': [('TRUMP', 115), ('US', 61), ('WHITE HOUSE', 46), ('DONALD TRUMP', 31), ('TRUMPS', 22), ('NEW YORK', 17), ('THE WHITE HOUSE', 15), ('CORONAVIRUS', 10), ('TIFFANY', 8), ('UK', 8)], 'nouns': [('TRUMP', 171), ('CORONAVIRUS', 123), ('PRESIDENT', 89), ('HOUSE', 68), ('WHITE', 65), ('US', 63), ('COVID-1', 35), ('DONALD', 31), ('TRUMPS', 29), ('NEW', 23)]}, {'examples': [(0.011648779587296407, 'Jeffrey Epstein’s ‘pimp’ Ghislaine Maxwell says ‘biggest mistake of her life’ was recruiting Prince Andrew sex accuser. GHISLAINE Maxwell has said her “biggest mistake” was luring Prince Andrews accuser into her and paedophile Jeffrey Epstein’s depraved world, it can be revealed. The 57-year-old, accused of being Epsteins pimp, is said to “not give a s**t” about Virginia Roberts-Giuffre, who claims to have had sex with the royal when she was 17, and []'), (0.011096467081344605, 'Jeffrey Epstein’s ‘madam’ Ghislaine Maxwell knew Prince Andrew’s accuser Virginia Roberts was 17 in unsealed court docs. GHISLAINE Maxwell knew Prince Andrews sex accuser Virginia Roberts was 17, unsealed cou ...
