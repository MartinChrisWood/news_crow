# %% [markdown]
# # Gauge the quality of the clusters produced - RSS corpus

# %%
import lib.reporter as reporter

# %%
from importlib import reload
reload(reporter)
lda_stats, lda_coherences, lda_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_lda.csv")
lda_stats
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-f97d523e07c7> in <module>
#       1 from importlib import reload
#       2 reload(reporter)
# ----> 3 lda_stats, lda_coherences, lda_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_lda.csv")
#       4 lda_stats
#
# D:\Martin\Documents\GitHub\news_crow\lib\reporter.py in report_corpus_model_coherence(data_path, cluster_column, text_column)
#     206     """
#     207     df = pd.read_csv(data_path)
# --> 208     df["tokens"] = df[text_column].apply(preprocess_description)
#     209
#     210     # Handles the coherence scoring
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# ...

# %%
from importlib import reload
reload(reporter)
w2v_stats, w2v_coherences, w2v_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_w2v_pca.csv")
w2v_stats
# Out:
# {'c_v': 0.537,
#  'c_npmi': 0.0509,
#  'macro_time_coherence': 1873835.7282091372,
#  'micro_time_coherence': 181447.58700317884,
#  'Average document word count': 39.30280635810531,
#  'Number of documents': 31393,
#  'Latest record': 'Fri, 01 May 2020 00:18:25 GMT',
#  'Earliest record': 'Wed, 9 Oct 2019 21:52:38 +0000',
#  'Number of clusters': 263,
#  'Median cluster size': 12.0,
#  'Percent clustered docs': 33.3,
#  'examples_best_performant': [['Coronavirus: Cyprus to pay holiday costs of infected tourists. The government will cover anyone who tests positive while on holiday on the Mediterranean island.',
#    'Coronavirus: Chinese hospital built in under two weeks is to close after last patients leave. Vice president of Leishenshan Hospital says more than 2,000 people were treated on its wards',
#    'Coronavirus: Greeks ponder ban on fax machines in state offices. The coronavirus has forced Greece to digitise the state and rapidly move public services online.',
# ...

# %%
from importlib import reload
reload(reporter)
net3_stats, net3_coherences, net3_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_louvain_3lim_permissive.csv")
net3_stats

# %%
from importlib import reload
reload(reporter)
net2_stats, net2_coherences, net2_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_louvain_2lim_permissive.csv")
net2_stats
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# {'c_v': 0.629,
#  'c_npmi': 0.0938,
#  'macro_time_coherence': 1387532.1998955887,
#  'micro_time_coherence': 157661.09942278653,
#  'Average document word count': 39.30280635810531,
#  'Number of documents': 31393,
#  'Latest record': 'Fri, 01 May 2020 00:18:25 GMT',
#  'Earliest record': 'Wed, 9 Oct 2019 21:52:38 +0000',
#  'Number of clusters': 197,
# ...

# %%
from importlib import reload
reload(reporter)
net2_stats, net2_coherences, net2_topics_results = reporter.report_corpus_model_coherence("working/RSS_clustered_louvain_2lim_tight.csv")
net2_stats
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# D:\Martin\Documents\GitHub\news_crow\lib\reporter.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
