# %% [markdown]
# # Gauge the quality of the clusters produced - RSS corpus
#
# TODO
# - Implement Silhouette scoring against TF-IDF representations

# %%
import re
import json
import gensim

import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

from gensim.models.coherencemodel import CoherenceModel
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS

from nltk.stem.porter import *
from lib import helper

# Define which stemmer to use in the pipeline later
stemmer = PorterStemmer()

# Useful flatten function from Alex Martelli on https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-list-of-lists
flatten = lambda l: [item for sublist in l for item in sublist]

# %matplotlib inline

# %%
from importlib import reload

# %%
reload(helper)
coherence_models, topics_features = helper.report_corpus_model_coherence("working/RSS_clustered_lda.csv")
# Out:
# c_v: 0.4682
# c_npmi: 0.0167
# Average document word count: 36.6154429662232
# Number of documents: 119964
# Latest record: Wed, 9 Oct 2019 23:01:00 +0000
# Earliest record: Fri, 01 May 2020 00:18:25 GMT
# Number of clusters: 48
# Median cluster size: 2406.5
# Clustered docs: 100.0%
#
# Best Performant (C_v)!
# 77     Iran to release crew of UK-flagged tanker, as ...
# 110    apos;I canapos;t breathe!apos;: Emergency radi...
# 131    California boat fire: Eight confirmed dead as ...
# 134    California boat fire: people feared dead as bo...
# Name: clean_text, dtype: object
# 27     Brexit turmoil continues as lawmakers defy UK'...
# 73     Jamaican womenapos;s football team go on strik...
# 96     EU considers designating no-deal Brexit as apo...
# 104    French schools ordered to display EU flags in ...
# Name: clean_text, dtype: object
# 5      Second US death linked to vaping is reported i...
# 28     Michigan State University fined record $4.5m o...
# ...

# %%
reload(helper)
coherence_models, topics_features = helper.report_corpus_model_coherence("working/RSS_clustered_w2v_pca.csv")
# Out:
# c_v: 0.4967
# c_npmi: 0.0545
# Average document word count: 36.6154429662232
# Number of documents: 119964
# Latest record: Wed, 9 Oct 2019 23:01:00 +0000
# Earliest record: Fri, 01 May 2020 00:18:25 GMT
# Number of clusters: 953
# Median cluster size: 12.0
# Clustered docs: 22.2%
#
# Best Performant (C_v)!
# 2571     MP John Mann resigns from Labour Party over an...
# 4247     Peerage for Retford MP in Theresa May's resign...
# 9387     Suspended MP set to speak at conference event....
# 18653    Changes to free bus travel rules in Wales on t...
# Name: clean_text, dtype: object
# 25161    Man accidentally wins Lotto jackpot twice beca...
# 38466    Actress reveals cult leader who hunted virgins...
# 81292    Virgin Australia staff are slammed by customer...
# 89722    Virgin Australia could soon collapse if govern...
# Name: clean_text, dtype: object
# 1558     Stacie Saggers mother of two-year-old allegedl...
# 4569     Grandad arrested after he sent vile messages i...
# ...

# %%
reload(helper)
coherence_models, topics_features = helper.report_corpus_model_coherence("working/RSS_clustered_w2v_direct.csv")
# Out:
# c_v: 0.5006
# c_npmi: 0.0553
# Average document word count: 36.6154429662232
# Number of documents: 119964
# Latest record: Wed, 9 Oct 2019 23:01:00 +0000
# Earliest record: Fri, 01 May 2020 00:18:25 GMT
# Number of clusters: 1024
# Median cluster size: 11.5
# Clustered docs: 23.0%
#
# Best Performant (C_v)!
# 15206    Inside hellish Syrian jail packed with hundred...
# 28642    5,000 infected ISIS militants in Syrian jails ...
# 37131    Turkey apos;bans cyanideapos; after spate of m...
# 44547    Saudi Arabia oil attacks: UN 'unable to confir...
# Name: clean_text, dtype: object
# 4024     Michael Schumacher is ‘conscious’ after being ...
# 4426     Opera glasses 'used by Abraham Lincoln's wife'...
# 9540     Man drowns attempting to propose to girlfriend...
# 16417    El Chapo's killers in danger from rivals after...
# Name: clean_text, dtype: object
# 265     Babies develop apos;werewolf syndromeapos; aft...
# 5775    Spain floods: Five killed and thousands evacua...
# ...

# %% [raw]
# reload(helper)
# coherence_models, topics_features = helper.report_corpus_model_coherence("working/RSS_clustered_louvain.csv")
